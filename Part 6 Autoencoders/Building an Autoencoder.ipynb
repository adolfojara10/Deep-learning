# %%
import numpy as np
import pandas as pd 
import torch 
import torch.nn as nn
import torch.nn.parallel 
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %% [markdown]
# # Importing the datasets

# %%
movies = pd.read_csv('movies.dat', sep='::', header=None, engine='python', encoding='latin-1')

# %%
users = pd.read_csv('users.dat', sep='::', header=None, engine='python', encoding='latin-1')

# %%
ratings = pd.read_csv('ratings.dat', sep='::', header=None, engine='python', encoding='latin-1')

# %% [markdown]
# # Prepare the training set

# %%
training_set = pd.read_csv('u1.base', delimiter='\t', header=None)
training_set.shape
# Out:
# (80000, 4)

# %%
training_set = np.array(training_set, dtype='int64')
training_set
# Out:
# array([[        1,         1,         5, 874965758],
#        [        1,         2,         3, 876893171],
#        [        1,         3,         4, 878542960],
#        ...,
#        [      943,      1188,         3, 888640250],
#        [      943,      1228,         3, 888640275],
#        [      943,      1330,         3, 888692465]], dtype=int64)

# %%
test_set = pd.read_csv('u1.test', delimiter='\t')

# %%
test_set = np.array(test_set, dtype='int64')
test_set
# Out:
# array([[        1,        10,         3, 875693118],
#        [        1,        12,         5, 878542960],
#        [        1,        14,         5, 874965706],
#        ...,
#        [      459,       934,         3, 879563639],
#        [      460,        10,         3, 882912371],
#        [      462,       682,         5, 886365231]], dtype=int64)

# %% [markdown]
# ## Getting the number of users and movies

# %%
nb_users = int(max(max(training_set[:, 0], ), max(test_set[:, 0])))
nb_movies = int(max(max(training_set[:, 1], ), max(test_set[:, 1])))

# %% [markdown]
# ## Converting the data into an array with users in lines and movies in columns

# %%
def convert(data):
  new_data = []
  for id_users in range(1, nb_users + 1):
    id_movies = data[:, 1] [data[:, 0] == id_users]
    id_ratings = data[:, 2] [data[:, 0] == id_users]
    ratings = np.zeros(nb_movies)
    ratings[id_movies - 1] = id_ratings
    new_data.append(list(ratings))
  return new_data
training_set = convert(training_set)
test_set = convert(test_set)

# %% [markdown]
# ## Converting the data into Torch tensors

# %%
training_set = torch.FloatTensor(training_set)
test_set = torch.FloatTensor(test_set)

# %% [markdown]
# # Create the architecture of the NN

# %%
#stack autoencoders
class SAE(nn.Module):

    def __init__(self,):
        super(SAE, self).__init__()
        #full connection
        #nn.Linear() it needs the number of inputs and the number of hidden neurons
        self.fc1 = nn.Linear(nb_movies, 20)
        
        #second full connection
        self.fc2 = nn.Linear(20,10)
        
        #third full connection where we start to decode
        self.fc3 = nn.Linear(10, 20)
        
        #fourth full connection
        self.fc4 = nn.Linear(20,nb_movies)
        
        #the activation function sigmoid
        self.activation = nn.Sigmoid()
    
    #for encoding
    def forward(self, x):
        #the activation function will activate the neurons for encodin and returns the vector encoded
        x = self.activation(self.fc1(x))
        #encoding in the 2 layer
        x = self.activation(self.fc2(x))
        #decoding in the 3 layer
        x = self.activation(self.fc3(x))
        #decoding in the 4 layer
        x = self.fc4(x)
        
        return x

# %%
sae = SAE()
criterion = nn.MSELoss()
#root mean square optimizer( all the parameters tha define the architecture of the NN, learning rate, the dacay to reduce
#   the learning rate after certain number of epochs)
optimizer = optim.RMSprop(sae.parameters(), lr=0.01, weight_decay= 0.5)

# %% [markdown]
# # Training the SAE

# %%
NUMBER_EPOCHS = 200

for epoch in range(1,NUMBER_EPOCHS+1):
    train_loss = 0
    #to save the users who at least rated one movie
    s = 0.
    
    for id_user in range(nb_users):
        input_user = Variable(training_set[id_user]).unsqueeze(0)
        target_user = input_user.clone()
        
        #to check if ht euser rated at least one movie
        if torch.sum(target_user.data > 0) > 0:
            output_prediction = sae.forward(input_user)
            #to reduce computations so we dont compute the gradient with the respective target
            target_user.require_grad = False
            #for the not rated movies so they stay the same
            output_prediction[target_user == 0] = 0
            
            loss = criterion(output_prediction, target_user)
            #to avoid the mean is 0 it's added 1e-10 and it is the average odf the rated movies
            mean_corrector = nb_movies/float(torch.sum(target_user.data > 0) + 1e-10) 
            
            #to decide to increase or decrease the value of the weights
            loss.backward()
            
            train_loss += np.sqrt(loss.data*mean_corrector)
            s += 1.
            
            #decides the intensity to upgrade the weights
            optimizer.step()
            
    print('epoch: ', str(epoch), ', loss: ', str(train_loss/s))
    #the loss represents the variation between the predicted rating and the real ones
# Out:
# epoch:  1 , loss:  tensor(0.9128)
# epoch:  2 , loss:  tensor(0.9127)
# epoch:  3 , loss:  tensor(0.9125)
# epoch:  4 , loss:  tensor(0.9124)
# epoch:  5 , loss:  tensor(0.9125)
# epoch:  6 , loss:  tensor(0.9117)
# epoch:  7 , loss:  tensor(0.9119)
# epoch:  8 , loss:  tensor(0.9118)
# epoch:  9 , loss:  tensor(0.9120)
# epoch:  10 , loss:  tensor(0.9116)
# epoch:  11 , loss:  tensor(0.9115)
# epoch:  12 , loss:  tensor(0.9110)
# epoch:  13 , loss:  tensor(0.9113)
# epoch:  14 , loss:  tensor(0.9108)
# epoch:  15 , loss:  tensor(0.9108)
# epoch:  16 , loss:  tensor(0.9107)
# epoch:  17 , loss:  tensor(0.9106)
# epoch:  18 , loss:  tensor(0.9105)
# epoch:  19 , loss:  tensor(0.9107)
# epoch:  20 , loss:  tensor(0.9105)
# epoch:  21 , loss:  tensor(0.9103)
# epoch:  22 , loss:  tensor(0.9103)
# epoch:  23 , loss:  tensor(0.9101)
# epoch:  24 , loss:  tensor(0.9099)
# epoch:  25 , loss:  tensor(0.9098)
# epoch:  26 , loss:  tensor(0.9098)
# epoch:  27 , loss:  tensor(0.9094)
# epoch:  28 , loss:  tensor(0.9095)
# epoch:  29 , loss:  tensor(0.9095)
# epoch:  30 , loss:  tensor(0.9095)
# epoch:  31 , loss:  tensor(0.9092)
# epoch:  32 , loss:  tensor(0.9090)
# epoch:  33 , loss:  tensor(0.9089)
# epoch:  34 , loss:  tensor(0.9089)
# epoch:  35 , loss:  tensor(0.9084)
# epoch:  36 , loss:  tensor(0.9085)
# epoch:  37 , loss:  tensor(0.9082)
# epoch:  38 , loss:  tensor(0.9083)
# epoch:  39 , loss:  tensor(0.9080)
# epoch:  40 , loss:  tensor(0.9080)
# epoch:  41 , loss:  tensor(0.9074)
# epoch:  42 , loss:  tensor(0.9077)
# epoch:  43 , loss:  tensor(0.9073)
# epoch:  44 , loss:  tensor(0.9075)
# epoch:  45 , loss:  tensor(0.9071)
# epoch:  46 , loss:  tensor(0.9071)
# epoch:  47 , loss:  tensor(0.9064)
# epoch:  48 , loss:  tensor(0.9063)
# epoch:  49 , loss:  tensor(0.9061)
# epoch:  50 , loss:  tensor(0.9060)
# epoch:  51 , loss:  tensor(0.9054)
# epoch:  52 , loss:  tensor(0.9057)
# epoch:  53 , loss:  tensor(0.9055)
# epoch:  54 , loss:  tensor(0.9055)
# epoch:  55 , loss:  tensor(0.9048)
# epoch:  56 , loss:  tensor(0.9050)
# epoch:  57 , loss:  tensor(0.9045)
# epoch:  58 , loss:  tensor(0.9043)
# epoch:  59 , loss:  tensor(0.9043)
# epoch:  60 , loss:  tensor(0.9044)
# epoch:  61 , loss:  tensor(0.9037)
# epoch:  62 , loss:  tensor(0.9033)
# epoch:  63 , loss:  tensor(0.9028)
# epoch:  64 , loss:  tensor(0.9028)
# epoch:  65 , loss:  tensor(0.9023)
# epoch:  66 , loss:  tensor(0.9025)
# epoch:  67 , loss:  tensor(0.9022)
# epoch:  68 , loss:  tensor(0.9018)
# epoch:  69 , loss:  tensor(0.9017)
# epoch:  70 , loss:  tensor(0.9012)
# epoch:  71 , loss:  tensor(0.9010)
# epoch:  72 , loss:  tensor(0.9009)
# epoch:  73 , loss:  tensor(0.9004)
# epoch:  74 , loss:  tensor(0.8997)
# epoch:  75 , loss:  tensor(0.8994)
# epoch:  76 , loss:  tensor(0.8993)
# epoch:  77 , loss:  tensor(0.8991)
# epoch:  78 , loss:  tensor(0.8987)
# epoch:  79 , loss:  tensor(0.8984)
# epoch:  80 , loss:  tensor(0.8985)
# epoch:  81 , loss:  tensor(0.8975)
# epoch:  82 , loss:  tensor(0.8974)
# epoch:  83 , loss:  tensor(0.8971)
# epoch:  84 , loss:  tensor(0.8967)
# epoch:  85 , loss:  tensor(0.8959)
# epoch:  86 , loss:  tensor(0.8987)
# epoch:  87 , loss:  tensor(0.8981)
# epoch:  88 , loss:  tensor(0.8969)
# epoch:  89 , loss:  tensor(0.8961)
# epoch:  90 , loss:  tensor(0.8961)
# epoch:  91 , loss:  tensor(0.8948)
# epoch:  92 , loss:  tensor(0.8945)
# epoch:  93 , loss:  tensor(0.8935)
# epoch:  94 , loss:  tensor(0.8931)
# epoch:  95 , loss:  tensor(0.8925)
# epoch:  96 , loss:  tensor(0.8920)
# epoch:  97 , loss:  tensor(0.8912)
# epoch:  98 , loss:  tensor(0.8912)
# epoch:  99 , loss:  tensor(0.8911)
# epoch:  100 , loss:  tensor(0.8905)
# epoch:  101 , loss:  tensor(0.8894)
# epoch:  102 , loss:  tensor(0.8890)
# epoch:  103 , loss:  tensor(0.8888)
# epoch:  104 , loss:  tensor(0.8887)
# epoch:  105 , loss:  tensor(0.8881)
# epoch:  106 , loss:  tensor(0.8876)
# epoch:  107 , loss:  tensor(0.8874)
# epoch:  108 , loss:  tensor(0.8877)
# epoch:  109 , loss:  tensor(0.8876)
# epoch:  110 , loss:  tensor(0.8862)
# epoch:  111 , loss:  tensor(0.8855)
# epoch:  112 , loss:  tensor(0.8850)
# epoch:  113 , loss:  tensor(0.8844)
# epoch:  114 , loss:  tensor(0.8842)
# epoch:  115 , loss:  tensor(0.8833)
# epoch:  116 , loss:  tensor(0.8829)
# epoch:  117 , loss:  tensor(0.8824)
# epoch:  118 , loss:  tensor(0.8831)
# epoch:  119 , loss:  tensor(0.8813)
# epoch:  120 , loss:  tensor(0.8810)
# epoch:  121 , loss:  tensor(0.8801)
# epoch:  122 , loss:  tensor(0.8803)
# epoch:  123 , loss:  tensor(0.8792)
# epoch:  124 , loss:  tensor(0.8789)
# epoch:  125 , loss:  tensor(0.8782)
# epoch:  126 , loss:  tensor(0.8780)
# epoch:  127 , loss:  tensor(0.8770)
# epoch:  128 , loss:  tensor(0.8766)
# epoch:  129 , loss:  tensor(0.8762)
# epoch:  130 , loss:  tensor(0.8766)
# epoch:  131 , loss:  tensor(0.8757)
# epoch:  132 , loss:  tensor(0.8753)
# epoch:  133 , loss:  tensor(0.8746)
# epoch:  134 , loss:  tensor(0.8744)
# epoch:  135 , loss:  tensor(0.8740)
# epoch:  136 , loss:  tensor(0.8738)
# epoch:  137 , loss:  tensor(0.8738)
# epoch:  138 , loss:  tensor(0.8731)
# epoch:  139 , loss:  tensor(0.8731)
# epoch:  140 , loss:  tensor(0.8724)
# epoch:  141 , loss:  tensor(0.8727)
# epoch:  142 , loss:  tensor(0.8719)
# epoch:  143 , loss:  tensor(0.8717)
# epoch:  144 , loss:  tensor(0.8716)
# epoch:  145 , loss:  tensor(0.8711)
# epoch:  146 , loss:  tensor(0.8715)
# epoch:  147 , loss:  tensor(0.8714)
# epoch:  148 , loss:  tensor(0.8698)
# epoch:  149 , loss:  tensor(0.8706)
# epoch:  150 , loss:  tensor(0.8696)
# epoch:  151 , loss:  tensor(0.8694)
# epoch:  152 , loss:  tensor(0.8686)
# epoch:  153 , loss:  tensor(0.8687)
# epoch:  154 , loss:  tensor(0.8679)
# epoch:  155 , loss:  tensor(0.8678)
# epoch:  156 , loss:  tensor(0.8671)
# epoch:  157 , loss:  tensor(0.8672)
# epoch:  158 , loss:  tensor(0.8669)
# epoch:  159 , loss:  tensor(0.8665)
# epoch:  160 , loss:  tensor(0.8661)
# epoch:  161 , loss:  tensor(0.8663)
# epoch:  162 , loss:  tensor(0.8658)
# epoch:  163 , loss:  tensor(0.8657)
# epoch:  164 , loss:  tensor(0.8649)
# epoch:  165 , loss:  tensor(0.8654)
# epoch:  166 , loss:  tensor(0.8644)
# epoch:  167 , loss:  tensor(0.8644)
# epoch:  168 , loss:  tensor(0.8639)
# epoch:  169 , loss:  tensor(0.8636)
# epoch:  170 , loss:  tensor(0.8628)
# epoch:  171 , loss:  tensor(0.8630)
# epoch:  172 , loss:  tensor(0.8632)
# epoch:  173 , loss:  tensor(0.8634)
# epoch:  174 , loss:  tensor(0.8623)
# epoch:  175 , loss:  tensor(0.8620)
# epoch:  176 , loss:  tensor(0.8617)
# epoch:  177 , loss:  tensor(0.8610)
# epoch:  178 , loss:  tensor(0.8610)
# epoch:  179 , loss:  tensor(0.8606)
# epoch:  180 , loss:  tensor(0.8602)
# epoch:  181 , loss:  tensor(0.8613)
# epoch:  182 , loss:  tensor(0.8606)
# epoch:  183 , loss:  tensor(0.8596)
# epoch:  184 , loss:  tensor(0.8593)
# epoch:  185 , loss:  tensor(0.8700)
# epoch:  186 , loss:  tensor(0.8695)
# epoch:  187 , loss:  tensor(0.8652)
# epoch:  188 , loss:  tensor(0.8639)
# epoch:  189 , loss:  tensor(0.8644)
# epoch:  190 , loss:  tensor(0.8630)
# epoch:  191 , loss:  tensor(0.8635)
# epoch:  192 , loss:  tensor(0.8623)
# epoch:  193 , loss:  tensor(0.8607)
# epoch:  194 , loss:  tensor(0.8598)
# epoch:  195 , loss:  tensor(0.8595)
# epoch:  196 , loss:  tensor(0.8593)
# epoch:  197 , loss:  tensor(0.8584)
# epoch:  198 , loss:  tensor(0.8583)
# epoch:  199 , loss:  tensor(0.8583)
# epoch:  200 , loss:  tensor(0.8579)

# %%
nb_epoch = 200
for epoch in range(1, nb_epoch + 1):
  train_loss = 0
  s = 0.
  for id_user in range(nb_users):
    input = Variable(training_set[id_user]).unsqueeze(0)
    target = input.clone()
    if torch.sum(target.data > 0) > 0:
      output = sae(input)
      target.require_grad = False
      output[target == 0] = 0
      loss = criterion(output, target)
      mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
      loss.backward()
      train_loss += np.sqrt(loss.data*mean_corrector)
      s += 1.
      optimizer.step()
  print('epoch: '+str(epoch)+'loss: '+ str(train_loss/s))
# Out:
# epoch: 1loss: tensor(1.7646)
# epoch: 2loss: tensor(1.0966)
# epoch: 3loss: tensor(1.0533)
# epoch: 4loss: tensor(1.0386)
# epoch: 5loss: tensor(1.0307)
# epoch: 6loss: tensor(1.0265)
# epoch: 7loss: tensor(1.0237)
# epoch: 8loss: tensor(1.0221)
# epoch: 9loss: tensor(1.0206)
# epoch: 10loss: tensor(1.0198)
# epoch: 11loss: tensor(1.0188)
# epoch: 12loss: tensor(1.0185)
# epoch: 13loss: tensor(1.0176)
# epoch: 14loss: tensor(1.0176)
# epoch: 15loss: tensor(1.0169)
# epoch: 16loss: tensor(1.0170)
# epoch: 17loss: tensor(1.0167)
# epoch: 18loss: tensor(1.0165)
# epoch: 19loss: tensor(1.0163)
# epoch: 20loss: tensor(1.0164)
# epoch: 21loss: tensor(1.0160)
# epoch: 22loss: tensor(1.0158)
# epoch: 23loss: tensor(1.0156)
# epoch: 24loss: tensor(1.0157)
# epoch: 25loss: tensor(1.0156)
# epoch: 26loss: tensor(1.0156)
# epoch: 27loss: tensor(1.0151)
# epoch: 28loss: tensor(1.0150)
# epoch: 29loss: tensor(1.0130)
# epoch: 30loss: tensor(1.0119)
# epoch: 31loss: tensor(1.0102)
# epoch: 32loss: tensor(1.0080)
# epoch: 33loss: tensor(1.0069)
# epoch: 34loss: tensor(1.0041)
# epoch: 35loss: tensor(1.0021)
# epoch: 36loss: tensor(0.9986)
# epoch: 37loss: tensor(0.9980)
# epoch: 38loss: tensor(0.9973)
# epoch: 39loss: tensor(0.9935)
# epoch: 40loss: tensor(0.9918)
# epoch: 41loss: tensor(0.9905)
# epoch: 42loss: tensor(0.9877)
# epoch: 43loss: tensor(0.9861)
# epoch: 44loss: tensor(0.9829)
# epoch: 45loss: tensor(0.9810)
# epoch: 46loss: tensor(0.9784)
# epoch: 47loss: tensor(0.9769)
# epoch: 48loss: tensor(0.9733)
# epoch: 49loss: tensor(0.9762)
# epoch: 50loss: tensor(0.9778)
# epoch: 51loss: tensor(0.9757)
# epoch: 52loss: tensor(0.9697)
# epoch: 53loss: tensor(0.9743)
# epoch: 54loss: tensor(0.9748)
# epoch: 55loss: tensor(0.9711)
# epoch: 56loss: tensor(0.9708)
# epoch: 57loss: tensor(0.9692)
# epoch: 58loss: tensor(0.9695)
# epoch: 59loss: tensor(0.9666)
# epoch: 60loss: tensor(0.9663)
# epoch: 61loss: tensor(0.9631)
# epoch: 62loss: tensor(0.9625)
# epoch: 63loss: tensor(0.9602)
# epoch: 64loss: tensor(0.9596)
# epoch: 65loss: tensor(0.9642)
# epoch: 66loss: tensor(0.9592)
# epoch: 67loss: tensor(0.9588)
# epoch: 68loss: tensor(0.9548)
# epoch: 69loss: tensor(0.9558)
# epoch: 70loss: tensor(0.9526)
# epoch: 71loss: tensor(0.9516)
# epoch: 72loss: tensor(0.9506)
# epoch: 73loss: tensor(0.9500)
# epoch: 74loss: tensor(0.9496)
# epoch: 75loss: tensor(0.9503)
# epoch: 76loss: tensor(0.9472)
# epoch: 77loss: tensor(0.9574)
# epoch: 78loss: tensor(0.9564)
# epoch: 79loss: tensor(0.9557)
# epoch: 80loss: tensor(0.9515)
# epoch: 81loss: tensor(0.9515)
# epoch: 82loss: tensor(0.9497)
# epoch: 83loss: tensor(0.9498)
# epoch: 84loss: tensor(0.9460)
# epoch: 85loss: tensor(0.9471)
# epoch: 86loss: tensor(0.9444)
# epoch: 87loss: tensor(0.9454)
# epoch: 88loss: tensor(0.9427)
# epoch: 89loss: tensor(0.9410)
# epoch: 90loss: tensor(0.9413)
# epoch: 91loss: tensor(0.9415)
# epoch: 92loss: tensor(0.9387)
# epoch: 93loss: tensor(0.9424)
# epoch: 94loss: tensor(0.9428)
# epoch: 95loss: tensor(0.9432)
# epoch: 96loss: tensor(0.9401)
# epoch: 97loss: tensor(0.9406)
# epoch: 98loss: tensor(0.9401)
# epoch: 99loss: tensor(0.9392)
# epoch: 100loss: tensor(0.9388)
# epoch: 101loss: tensor(0.9384)
# epoch: 102loss: tensor(0.9376)
# epoch: 103loss: tensor(0.9378)
# epoch: 104loss: tensor(0.9358)
# epoch: 105loss: tensor(0.9361)
# epoch: 106loss: tensor(0.9353)
# epoch: 107loss: tensor(0.9358)
# epoch: 108loss: tensor(0.9340)
# epoch: 109loss: tensor(0.9346)
# epoch: 110loss: tensor(0.9332)
# epoch: 111loss: tensor(0.9328)
# epoch: 112loss: tensor(0.9323)
# epoch: 113loss: tensor(0.9322)
# epoch: 114loss: tensor(0.9309)
# epoch: 115loss: tensor(0.9314)
# epoch: 116loss: tensor(0.9302)
# epoch: 117loss: tensor(0.9303)
# epoch: 118loss: tensor(0.9287)
# epoch: 119loss: tensor(0.9294)
# epoch: 120loss: tensor(0.9283)
# epoch: 121loss: tensor(0.9287)
# epoch: 122loss: tensor(0.9275)
# epoch: 123loss: tensor(0.9282)
# epoch: 124loss: tensor(0.9271)
# epoch: 125loss: tensor(0.9276)
# epoch: 126loss: tensor(0.9265)
# epoch: 127loss: tensor(0.9263)
# epoch: 128loss: tensor(0.9251)
# epoch: 129loss: tensor(0.9262)
# epoch: 130loss: tensor(0.9247)
# epoch: 131loss: tensor(0.9252)
# epoch: 132loss: tensor(0.9244)
# epoch: 133loss: tensor(0.9247)
# epoch: 134loss: tensor(0.9236)
# epoch: 135loss: tensor(0.9240)
# epoch: 136loss: tensor(0.9229)
# epoch: 137loss: tensor(0.9236)
# epoch: 138loss: tensor(0.9227)
# epoch: 139loss: tensor(0.9228)
# epoch: 140loss: tensor(0.9218)
# epoch: 141loss: tensor(0.9222)
# epoch: 142loss: tensor(0.9217)
# epoch: 143loss: tensor(0.9215)
# epoch: 144loss: tensor(0.9207)
# epoch: 145loss: tensor(0.9212)
# epoch: 146loss: tensor(0.9206)
# epoch: 147loss: tensor(0.9211)
# epoch: 148loss: tensor(0.9202)
# epoch: 149loss: tensor(0.9205)
# epoch: 150loss: tensor(0.9203)
# epoch: 151loss: tensor(0.9198)
# epoch: 152loss: tensor(0.9198)
# epoch: 153loss: tensor(0.9198)
# epoch: 154loss: tensor(0.9196)
# epoch: 155loss: tensor(0.9194)
# epoch: 156loss: tensor(0.9193)
# epoch: 157loss: tensor(0.9191)
# epoch: 158loss: tensor(0.9190)
# epoch: 159loss: tensor(0.9184)
# epoch: 160loss: tensor(0.9181)
# epoch: 161loss: tensor(0.9182)
# epoch: 162loss: tensor(0.9181)
# epoch: 163loss: tensor(0.9177)
# epoch: 164loss: tensor(0.9174)
# epoch: 165loss: tensor(0.9175)
# epoch: 166loss: tensor(0.9173)
# epoch: 167loss: tensor(0.9173)
# epoch: 168loss: tensor(0.9169)
# epoch: 169loss: tensor(0.9166)
# epoch: 170loss: tensor(0.9164)
# epoch: 171loss: tensor(0.9167)
# epoch: 172loss: tensor(0.9166)
# epoch: 173loss: tensor(0.9165)
# epoch: 174loss: tensor(0.9162)
# epoch: 175loss: tensor(0.9159)
# epoch: 176loss: tensor(0.9161)
# epoch: 177loss: tensor(0.9155)
# epoch: 178loss: tensor(0.9159)
# epoch: 179loss: tensor(0.9157)
# epoch: 180loss: tensor(0.9153)
# epoch: 181loss: tensor(0.9151)
# epoch: 182loss: tensor(0.9152)
# epoch: 183loss: tensor(0.9151)
# epoch: 184loss: tensor(0.9151)
# epoch: 185loss: tensor(0.9150)
# epoch: 186loss: tensor(0.9146)
# epoch: 187loss: tensor(0.9144)
# epoch: 188loss: tensor(0.9146)
# epoch: 189loss: tensor(0.9146)
# epoch: 190loss: tensor(0.9143)
# epoch: 191loss: tensor(0.9139)
# epoch: 192loss: tensor(0.9138)
# epoch: 193loss: tensor(0.9137)
# epoch: 194loss: tensor(0.9138)
# epoch: 195loss: tensor(0.9134)
# epoch: 196loss: tensor(0.9135)
# epoch: 197loss: tensor(0.9137)
# epoch: 198loss: tensor(0.9134)
# epoch: 199loss: tensor(0.9133)
# epoch: 200loss: tensor(0.9126)

# %% [markdown]
# # Testing the SAE

# %%
test_loss = 0
s = 0.
for id_user in range(nb_users):
    #the ratings
    input = Variable(training_set[id_user]).unsqueeze(0)
    #contains the real rating of the movies
    target = Variable(test_set[id_user]).unsqueeze(0)
    if torch.sum(target.data > 0) > 0:
        output = sae(input)
        target.require_grad = False
        output[target == 0] = 0
        loss = criterion(output, target)
        mean_corrector = nb_movies/float(torch.sum(target.data > 0) + 1e-10)
        test_loss += np.sqrt(loss.data*mean_corrector)
        s += 1.
print('test loss: '+str(test_loss/s))
# Out:
# test loss: tensor(0.9509)
